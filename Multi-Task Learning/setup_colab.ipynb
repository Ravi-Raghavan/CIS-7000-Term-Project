# %% [markdown]
# # SPA-MSJF — Google Colab Setup
# Run each cell in order. GPU runtime recommended: Runtime → Change runtime type → T4 GPU

# %%
# 1. Clone the repo
# !git clone https://github.com/taherk-robo/CIS-7000-Term-Project.git
# %cd CIS-7000-Term-Project/Multi-Task\ Learning

# %%
# 2. Install dependencies (PyTorch already present on Colab — just extras)
# !pip install -r requirements.txt --quiet

# %%
# 3. Verify GPU
import torch
cuda = torch.cuda.is_available()
gpu  = torch.cuda.get_device_name(0) if cuda else 'N/A'
print(f'PyTorch {torch.__version__}  |  CUDA: {cuda}  |  GPU: {gpu}')

# %%
# 4. Run training
# !python3 train.py
